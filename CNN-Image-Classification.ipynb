# %% [markdown]
# <a href="https://www.kaggle.com/code/tompaulat/cnn-classifying-architectural-photography?scriptVersionId=108837894" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Is a CNN Able to Classify Fotos (Interior vs. Exterior) of Modern Architecure?

# %% [markdown]
# ![CNN.png](attachment:eedbcc60-4721-4eb1-9a29-86a39b7d62ef.png)

# %% [markdown]
# ## Imports

# %%
# imports 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os
from sklearn.model_selection import train_test_split

from IPython.display import Markdown, display, HTML

def printmd(string):
    display(Markdown(string))

from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import Activation, Dropout, Flatten, Dense

np.random.seed(2020)

# %% [markdown]
# # Loading in the Image Arrays (.npy)

# %% [markdown]
# We will use the [dataset on Modern Architecture](https://www.kaggle.com/datasets/tompaulat/modern-architecture-100k-small-images).

# %%
appart_path = '../input/modern-architecture-100k-small-images/Dataset_128px_128px_Images/Appartments'
appart_files = [f for f in os.listdir(appart_path)]

df = pd.DataFrame()
df['Names']= appart_files
df['Img_array'] = list(np.load('../input/modern-architecture-100k-small-images/Dataset_128px_128px_Images/Image_Array_Appart.npy'))

# %% [markdown]
# See [Exploring Images of Modern Architecture](https://www.kaggle.com/code/tompaulat/exploring-images-of-modern-architecture) to get an introduction to the data. There we have determined that the images are labeled with whether the foto was taken from the outside or inside. Therefore we append this information to the dataset.

# %%
exterior_list = []
interior_list = []
for i, rows in df.iterrows():
    if 'Interior' in rows[0]:
        interior_list.append(1)
        exterior_list.append(0)
    elif 'Exterior' in rows[0]:
        interior_list.append(0)
        exterior_list.append(1)
    else: 
        interior_list.append(0)
        exterior_list.append(0)
        
df['Exterior'] = exterior_list
df['Interior'] = interior_list

# %% [markdown]
# Now we create a dataframe only containing img_array if either `Exterior==1` or `Interior==1`

# %%
df_binary = df.query('Exterior == 1 | Interior == 1')
print(f'There are {df_binary.shape[0]} images classified as either a Interior Photography ({sum(list(df_binary.Interior))}) or Exterior Photography ({sum(list(df_binary.Exterior))})')
# Out:
# There are 24640 images classified as either a Interior Photography (16121) or Exterior Photography (8519)

# %%
# clear df from RAM
import gc
del df
gc.collect()
# Out:
# 47

# %% [markdown]
# # Downsampling Image Data

# %% [markdown]
# Let first downsample the Interior Images to have a balanced dataset. This loses some data (other approaches will be studied in the future).

# %%
df_model = df_binary.query('Interior==1').sample(sum(list(df_binary.Exterior)))
df_model = pd.concat([df_model, df_binary.query('Exterior==1')])

del df_binary
gc.collect()
# Out:
# 0

# %%
print(f'After downsampling there are {df_model.shape[0]} images classified as either a Interior Photography ({sum(list(df_model.Interior))}) or Exterior Photography ({sum(list(df_model.Exterior))})')
# Out:
# After downsampling there are 17038 images classified as either a Interior Photography (8519) or Exterior Photography (8519)

# %% [markdown]
# # Create Train and Test Sets

# %% [markdown]
# Now we can split the data first into the data and labels.

# %%
## Defining the train test split 
data = df_model.Img_array.to_list()
labels = df_model.Exterior.to_list()
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# %% [markdown]
# For the prediction label we used whether the image was taken from outside (`Exterior=1`) or inside (`Exterior=0`)
# Lets examine the two lists

# %%
## Defining the train test split 
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

del data, labels
gc.collect()
# Out:
# 69

# %%
X_train = np.asarray(X_train)
X_test = np.asarray(X_test)
y_train = np.asarray(y_train)
y_test = np.asarray(y_test)

# %% [markdown]
# # Defining the CNN

# %%
INPUT_SHAPE = (128, 128, 3)   #change to (SIZE, SIZE, 3)

model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=INPUT_SHAPE))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), kernel_initializer = 'he_uniform'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), kernel_initializer = 'he_uniform'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(1))
model.add(Activation('sigmoid'))
# Out:
# 2022-10-22 15:27:33.614062: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-22 15:27:33.715762: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-22 15:27:33.716784: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-22 15:27:33.718605: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-22 15:27:33.718915: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-22 15:27:33.719846: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-22 15:27:33.720829: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-22 15:27:36.114067: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-22 15:27:36.114972: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-22 15:27:36.115652: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-22 15:27:36.116230: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',         #also try adam
              metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 32)      896
# _________________________________________________________________
# activation (Activation)      (None, 126, 126, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 61, 61, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 28, 28, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                802880
# _________________________________________________________________
# activation_3 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# _________________________________________________________________
# activation_4 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 831,585
# Trainable params: 831,585
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # Visualizing the CNN layers (feature maps)

# %%
# Lets read in some image
img = load_img('../input/modern-architecture-100k-small-images/Dataset_128px_128px_Images/Appartments/08 Albatross Avenue House Studio Workshop Facade .jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128>

# %% [markdown]
# ## How is this image passed through the feature maps?

# %%
for i in [1, 3, 6]:
    model_layer = Model(inputs=model.inputs, outputs=model.layers[i].output)
    img = load_img('../input/modern-architecture-100k-small-images/Dataset_128px_128px_Images/Appartments/08 Albatross Avenue House Studio Workshop Facade .jpg')
    # convert the image to an array
    img = img_to_array(img)
    # expand dimensions so that it represents a single 'sample'
    img = np.expand_dims(img, axis=0)
    # prepare the image (e.g. scale pixel values for the vgg)

    # get feature map 
    feature_maps = model_layer.predict(img)
    # plot the output from each block
    square = 4
    ix = 1
    plt.figure(figsize=(15,15))
    printmd(f"# *Feature Map of Layer {i}*")
    for _ in range(square):
        for _ in range(square):
        # specify subplot and turn of axis
            ax = plt.subplot(square, square, ix)
            ax.set_xticks([])
            ax.set_yticks([])
            # plot filter channel in grayscale
            plt.imshow(feature_maps[0, :, :, ix-1], cmap='magma')
            ix += 1
    plt.show()
del model_layer, feature_maps
gc.collect()
# Out:
# 2022-10-22 15:27:36.759793: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-10-22 15:27:37.776143: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# # *Feature Map of Layer 1*
# # *Feature Map of Layer 3*
# # *Feature Map of Layer 6*
# 276

# %% [markdown]
# # Running the Model

# %%
gc.collect()
history = model.fit(X_train, 
                         y_train, 
                         batch_size = 64, 
                         verbose = 1, 
                         epochs = 20,      
                         validation_data=(X_test,y_test),
                         shuffle = True,
                     )


model.save('Photography_Classifier_h5')
# Out:
# 2022-10-22 15:27:46.304915: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 669941760 exceeds 10% of free system memory.
# 2022-10-22 15:27:47.095354: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 669941760 exceeds 10% of free system memory.
# Epoch 1/30
# 426/426 [==============================] - ETA: 0s - loss: 2.8495 - accuracy: 0.6713
# 2022-10-22 15:27:51.922635: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 167510016 exceeds 10% of free system memory.
# 2022-10-22 15:27:52.130531: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 167510016 exceeds 10% of free system memory.
# 426/426 [==============================] - 5s 9ms/step - loss: 2.8495 - accuracy: 0.6713 - val_loss: 0.4223 - val_accuracy: 0.8269
# Epoch 2/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.4484 - accuracy: 0.7571 - val_loss: 0.3741 - val_accuracy: 0.8322
# Epoch 3/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.4774 - accuracy: 0.7588 - val_loss: 0.3369 - val_accuracy: 0.8674
# Epoch 4/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.3971 - accuracy: 0.8387 - val_loss: 0.2790 - val_accuracy: 0.8903
# Epoch 5/30
# 426/426 [==============================] - 4s 8ms/step - loss: 0.4160 - accuracy: 0.8346 - val_loss: 0.2948 - val_accuracy: 0.8850
# Epoch 6/30
# 426/426 [==============================] - 4s 9ms/step - loss: 0.3644 - accuracy: 0.8580 - val_loss: 0.2665 - val_accuracy: 0.8991
# Epoch 7/30
# 426/426 [==============================] - 4s 9ms/step - loss: 0.3491 - accuracy: 0.8635 - val_loss: 0.2611 - val_accuracy: 0.8929
# Epoch 8/30
# 426/426 [==============================] - 4s 8ms/step - loss: 0.3488 - accuracy: 0.8648 - val_loss: 0.2791 - val_accuracy: 0.8917
# Epoch 9/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.3227 - accuracy: 0.8684 - val_loss: 0.2710 - val_accuracy: 0.8785
# Epoch 10/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.3172 - accuracy: 0.8755 - val_loss: 0.2645 - val_accuracy: 0.8920
# Epoch 11/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.3103 - accuracy: 0.8776 - val_loss: 0.2607 - val_accuracy: 0.8999
# Epoch 12/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.3148 - accuracy: 0.8811 - val_loss: 0.2893 - val_accuracy: 0.8911
# Epoch 13/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.2946 - accuracy: 0.8842 - val_loss: 0.3271 - val_accuracy: 0.8779
# Epoch 14/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.2771 - accuracy: 0.8935 - val_loss: 0.2687 - val_accuracy: 0.8935
# Epoch 15/30
# 426/426 [==============================] - 4s 9ms/step - loss: 0.2845 - accuracy: 0.8871 - val_loss: 0.2806 - val_accuracy: 0.8823
# Epoch 16/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.2831 - accuracy: 0.8919 - val_loss: 0.2758 - val_accuracy: 0.8973
# Epoch 17/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.2594 - accuracy: 0.8999 - val_loss: 0.3073 - val_accuracy: 0.8864
# Epoch 18/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.2520 - accuracy: 0.9014 - val_loss: 0.3580 - val_accuracy: 0.8888
# Epoch 19/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.2464 - accuracy: 0.9030 - val_loss: 0.3073 - val_accuracy: 0.8806
# Epoch 20/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.2465 - accuracy: 0.9020 - val_loss: 0.3160 - val_accuracy: 0.8970
# Epoch 21/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.2446 - accuracy: 0.9016 - val_loss: 0.3195 - val_accuracy: 0.8900
# Epoch 22/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.2378 - accuracy: 0.9114 - val_loss: 0.3189 - val_accuracy: 0.8835
# Epoch 23/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.2229 - accuracy: 0.9104 - val_loss: 0.3304 - val_accuracy: 0.9026
# Epoch 24/30
# 426/426 [==============================] - 4s 9ms/step - loss: 0.2200 - accuracy: 0.9125 - val_loss: 0.3100 - val_accuracy: 0.8932
# Epoch 25/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.2035 - accuracy: 0.9214 - val_loss: 0.3094 - val_accuracy: 0.8932
# Epoch 26/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.1977 - accuracy: 0.9230 - val_loss: 0.3902 - val_accuracy: 0.8935
# Epoch 27/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.1931 - accuracy: 0.9257 - val_loss: 0.5260 - val_accuracy: 0.8812
# Epoch 28/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.1797 - accuracy: 0.9275 - val_loss: 0.4555 - val_accuracy: 0.8938
# Epoch 29/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.1699 - accuracy: 0.9319 - val_loss: 0.3518 - val_accuracy: 0.8923
# Epoch 30/30
# 426/426 [==============================] - 3s 8ms/step - loss: 0.1837 - accuracy: 0.9288 - val_loss: 0.3960 - val_accuracy: 0.8817
# 2022-10-22 15:29:33.385484: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.

# %% [markdown]
# # Visualizing the Model Accuracy

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Example Images: Prediction vs True Labels

# %% [markdown]
# As a reminder label we used to classify:
# * `y_test` = 1 $\rightarrow$ Image show the outside of the building
# * `y_test` = 0 $\rightarrow$ Image show the inside of the building

# %%
np.random.seed(43)
random_idxs = np.random.choice(np.arange(X_test.shape[0]),10)

# %%
for i in random_idxs:
    img = X_test[i]
    plt.figure()
    input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
    print('________________________________')
    print("The prediction for this image is: ", model.predict(input_img).squeeze())
    print("The actual label for this image is: ", y_test[i])
    ## change cmap if prediction is not equal to the actual label
    if int(np.round(model.predict(input_img).squeeze())) != y_test[i]:
        display(HTML('<h2 style="color:red">This image is falsely predicted.</h2>'))
    plt.imshow(img[...,::-1])
    plt.show()
# Out:
# ________________________________
# The prediction for this image is:  9.583271e-06
# The actual label for this image is:  0
# ________________________________
# The prediction for this image is:  0.000693814
# The actual label for this image is:  0
# ________________________________
# The prediction for this image is:  0.9983297
# The actual label for this image is:  1
# ________________________________
# The prediction for this image is:  0.9978671
# The actual label for this image is:  1
# ________________________________
# The prediction for this image is:  2.107177e-05
# The actual label for this image is:  0
# ________________________________
# The prediction for this image is:  0.9984054
# The actual label for this image is:  1
# ________________________________
# The prediction for this image is:  0.9999672
# The actual label for this image is:  1
# ________________________________
# The prediction for this image is:  0.9967514
# The actual label for this image is:  1
# ________________________________
# The prediction for this image is:  1.0
# The actual label for this image is:  1
# ________________________________
# The prediction for this image is:  0.18857893
# The actual label for this image is:  0

# %% [markdown]
# ## Confusion Matrix

# %%
from keras.models import load_model
from sklearn.metrics import confusion_matrix
import seaborn as sns

_, acc = model.evaluate(X_test, y_test)
print("The accuracy of the model = ", (acc * 100.0), "%")
pred = model.predict(X_test)
ypred = (pred > 0.5)
cm = confusion_matrix(y_test, ypred)
f = sns.heatmap(cm, annot=True, fmt='d')
f.set(xlabel='Predicted Labels', ylabel='True Labels')

plt.show()
# Out:
# 107/107 [==============================] - 0s 3ms/step - loss: 0.3960 - accuracy: 0.8817
# The accuracy of the model =  88.17488551139832 %
